# %%
import matplotlib.pyplot as plt

# %%
R_PEAK_PER_CORE = 1.5 * 4
R_PEAK_PER_CORE_80 = 1.5 * 4 * 0.8

R_PEAK = R_PEAK_PER_CORE * 4
R_PEAK_80 = R_PEAK_PER_CORE * 4 * 0.8

# %%
# Gflops vs NB for 1 core using 80% memory.

nb = [
    32,
    40,
    48,
    56,
    64,
    72,
    80,
    88,
    96,
    104,
    112,
    120,
    128,
    136,
    144,
    152,
    160,
    168,
    176,
    184,
    192,
    200,
    208,
    216,
    224,
    232,
    240,
    248,
    256
]

openblas = [
    3.473700,
    3.989700,
    3.819500,
    4.270100,
    4.159700,
    4.424600,
    4.265700,
    4.503600,
    4.428300,
    4.662200,
    4.506700,
    4.713600,
    4.771000,
    4.457600,
    4.472000,
    4.470000,
    4.527900,
    4.565600,
    4.566900,
    4.584800,
    4.633900,
    4.611000,
    4.621900,
    4.605200,
    4.519900,
    4.752900,
    4.702300,
    4.775600,
    4.751900
]

blis = [
    3.035700,
    3.318300,
    3.475300,
    3.656400,
    3.771600,
    3.948000,
    4.029700,
    4.106700,
    4.246700,
    4.270000,
    4.341900,
    4.390800,
    4.214900,
    4.490500,
    4.302800,
    4.558400,
    4.642200,
    4.671200,
    4.656800,
    4.698700,
    4.533900,
    4.734500,
    4.803800,
    4.811500,
    4.861100,
    4.891600,
    4.873000,
    4.512900,
    4.304400
]

plt.figure(figsize=(12, 10))
plt.title("$R_{max}$ vs NB 1 Core 80% Memory")
plt.plot([32, 256], [R_PEAK_PER_CORE_80, R_PEAK_PER_CORE_80], ":", markersize=4, color="red")
plt.plot(nb, openblas, "-go", markersize=4)
plt.plot(nb, blis, "-bo", markersize=4)
plt.xlabel("NB")
plt.ylabel("$R_{max}$ (Gflops)")
plt.legend(["80% $R_{peak}$", "OpenBLAS $R_{max}$", "BLIS $R_{max}$"])
plt.grid()
plt.savefig("gflops_vs_nb_1_core_80_percent_memory.pdf")
plt.savefig("gflops_vs_nb_1_core_80_percent_memory.png")
plt.show()

# %%
# Gflops vs NB for 1 node using 80% memory.

nb = [
    32,
    40,
    48,
    56,
    64,
    72,
    80,
    88,
    96,
    104,
    112,
    120,
    128,
    136,
    144,
    152,
    160,
    168,
    176,
    184,
    192,
    200,
    208,
    216,
    224,
    232,
    240,
    248,
    256
]

openblas = [
    9.7850e+00,
    1.1479e+01,
    1.2017e+01,
    1.3060e+01,
    1.3083e+01,
    1.3811e+01,
    1.3599e+01,
    1.4011e+01,
    1.3829e+01,
    1.4035e+01,
    1.3950e+01,
    1.4049e+01,
    1.3909e+01,
    1.3251e+01,
    1.3567e+01,
    1.3777e+01,
    1.3537e+01,
    1.3718e+01,
    1.3907e+01,
    1.3866e+01,
    1.3795e+01,
    1.3688e+01,
    1.3772e+01,
    1.4085e+01,
    1.3572e+01,
    1.3967e+01,
    1.3515e+01,
    1.3532e+01,
    1.3475e+01
]

blis = [
    9.0592e+00,
    1.0219e+01,
    1.1080e+01,
    1.1668e+01,
    1.2576e+01,
    1.3056e+01,
    1.3508e+01,
    1.3814e+01,
    1.4046e+01,
    1.4349e+01,
    1.4542e+01,
    1.4730e+01,
    1.4854e+01,
    1.4943e+01,
    1.4971e+01,
    1.5074e+01,
    1.4937e+01,
    1.5045e+01,
    1.4795e+01,
    1.4631e+01,
    1.4839e+01,
    1.4613e+01,
    1.4253e+01,
    1.3617e+01,
    1.2454e+01,
    1.2401e+01,
    1.1397e+01,
    1.0445e+01,
    1.0469e+01,
]

plt.figure(figsize=(12, 10))
plt.title("$R_{max}$ vs NB 1 Node (4 Cores) 80% Memory")
plt.plot([32, 256], [R_PEAK_80, R_PEAK_80], ":", markersize=4, color="red")
plt.plot(nb, openblas, "-go", markersize=4)
plt.plot(nb, blis, "-bo", markersize=4)
plt.xlabel("NB")
plt.ylabel("$R_{max}$ (Gflops)")
plt.legend(["80% $R_{peak}$", "OpenBLAS $R_{max}$", "BLIS $R_{max}$"])
plt.grid()
plt.savefig("gflops_vs_nb_1_node_80_percent_memory.pdf")
plt.savefig("gflops_vs_nb_1_node_80_percent_memory.png")
plt.show()

# %%
# Gflops vs NB for 2 nodes using 80% memory.

nb = [
    32,
    40,
    48,
    56,
    64,
    72,
    80,
    88,
    96,
    104,
    112,
    120,
    128,
    136,
    144,
    152,
    160,
    168,
    176,
    184,
    192,
    200,
    208,
    216,
    224,
    232,
    240,
    248,
    256
]

openblas = [
    17.535000,
    20.623000,
    22.013000,
    23.659000,
    23.949000,
    24.787000,
    24.989000,
    25.852000,
    25.246000,
    25.700000,
    25.656000,
    26.062000,
    24.723000,
    24.140000,
    24.693000,
    24.577000,
    24.891000,
    24.791000,
    25.186000,
    25.473000,
    25.403000,
    26.009000,
    25.298000,
    25.589000,
    25.265000,
    25.382000,
    24.865000,
    25.219000,
    24.432000
]

blis = [
    16.511000,
    18.782000,
    20.914000,
    21.916000,
    22.410000,
    23.987000,
    24.874000,
    25.389000,
    25.618000,
    26.250000,
    26.542000,
    26.780000,
    26.411000,
    26.570000,
    27.215000,
    27.151000,
    27.625000,
    27.742000,
    27.609000,
    27.048000,
    26.626000,
    27.075000,
    26.506000,
    25.325000,
    23.989000,
    22.937000,
    21.456000,
    19.933000,
    20.000000
]

plt.figure(figsize=(12, 10))
plt.title("$R_{max}$ vs NB 2 Nodes 80% Memory")
plt.plot(nb, openblas, "-go", markersize=4)
plt.plot(nb, blis, "-bo", markersize=4)
plt.xlabel("NB")
plt.ylabel("$R_{max}$ (Gflops)")
plt.legend(["OpenBLAS", "BLIS"])
plt.grid()
plt.savefig("gflops_vs_nb_2_node_80_percent_memory.pdf")
plt.savefig("gflops_vs_nb_2_node_80_percent_memory.png")
plt.show()

# %%
# Gflops vs Nodes using 80% memory.

nodes = [1, 2, 3, 4, 5, 6, 7, 8]

r_peak_80 = [
    R_PEAK_80 * 1 * 0.8,
    R_PEAK_80 * 2 * 0.8,
    R_PEAK_80 * 3 * 0.8,
    R_PEAK_80 * 4 * 0.8,
    R_PEAK_80 * 5 * 0.8,
    R_PEAK_80 * 6 * 0.8,
    R_PEAK_80 * 7 * 0.8,
    R_PEAK_80 * 8 * 0.8
]

openblas = [
    1.4085e+01,
    2.6062e+01,
    0,
    0,
    0,
    0,
    0,
    0   
]

blis = [
    1.5074e+01,
    2.7742e+01,
    0,
    0,
    0,
    0,
    0,
    1.0166e+02  
]


plt.figure(figsize=(12, 10))
plt.title("$R_{max}$ vs Nodes 80% Memory")
plt.plot(nodes, r_peak_80, ":r", markersize=4)
plt.plot([1, 2], [1.4085e+01, 2.6062e+01], "-go", markersize=4)
#plt.plot(nodes, openblas_linear_scaling, ":g", markersize=5)
plt.plot([1, 2, 8], [1.5074e+01, 2.7742e+01, 1.0166e+02], "-bo", markersize=4)
#plt.plot(nodes, blis_linear_scaling, ":b", markersize=5)
plt.xlabel("Nodes")
plt.ylabel("$R_{max}$ (Gflops)")
plt.legend([ "80% $R_{peak}$", "OpenBLAS $R_{max}$ NB=120", "BLIS $R_{max}$ NB=168"])
plt.grid()
plt.savefig("gflops_vs_nodes_80_percent_memory.pdf")
plt.savefig("gflops_vs_nodes_80_percent_memory.png")
plt.show()
