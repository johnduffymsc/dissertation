# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20})

# %%
R_PEAK_PER_CORE = 1.5 * 4
R_PEAK_PER_CORE_80 = 1.5 * 4 * 0.8

R_PEAK = R_PEAK_PER_CORE * 4
R_PEAK_80 = R_PEAK_PER_CORE * 4 * 0.8

# %%
# Pure OpenMPI Gflops vs NB for 1 core using 80% memory.

nb = [
    32,
    40,
    48,
    56,
    64,
    72,
    80,
    88,
    96,
    104,
    112,
    120,
    128,
    136,
    144,
    152,
    160,
    168,
    176,
    184,
    192,
    200,
    208,
    216,
    224,
    232,
    240,
    248,
    256
]

openblas_serial = [
    3.4686e+00,
    3.9921e+00,
    3.8529e+00,
    3.8529e+00,
    4.1839e+00,
    4.4584e+00,
    4.2737e+00,
    4.5311e+00,
    4.4028e+00,
    4.6532e+00,
    4.5232e+00,
    4.7335e+00,
    4.7728e+00,
    4.4889e+00,
    4.4799e+00,
    4.5075e+00,
    4.4984e+00,
    4.5664e+00,
    4.5992e+00,
    4.6183e+00,
    4.6350e+00,
    4.6362e+00,
    4.6216e+00,
    4.6106e+00,
    4.5275e+00,
    4.7546e+00,
    4.7214e+00,
    4.8040e+00,
    4.7719e+00
]

blis_serial = [
    3.0090e+00,
    3.2991e+00,
    3.4946e+00,
    3.6728e+00,
    3.7907e+00,
    3.9483e+00,
    4.0667e+00,
    4.1396e+00,
    4.2657e+00,
    4.3243e+00,
    4.3680e+00,
    4.4238e+00,
    4.2614e+00,
    4.5209e+00,
    4.3277e+00,
    4.5628e+00,
    4.6193e+00,
    4.6712e+00,
    4.6974e+00,
    4.7231e+00,
    4.5742e+00,
    4.7834e+00,
    4.8235e+00,
    4.8318e+00,
    4.8608e+00,
    4.8990e+00,
    4.8906e+00,
    4.5435e+00,
    4.3665e+00
]

plt.figure(figsize=(12, 10))
#plt.title("Baseline $R_{max}$ vs NB 1 Core 80% Memory")
plt.plot([32, 256], [R_PEAK_PER_CORE_80, R_PEAK_PER_CORE_80], ":", markersize=6, color="red")
plt.plot(nb, openblas_serial, "-go", markersize=6)
plt.plot(nb, blis_serial, "-bo", markersize=6)
plt.xlabel("NB")
plt.ylabel("$R_{max}$ (Gflops)")
plt.legend(["80% $R_{peak}$", "OpenBLAS Serial", "BLIS Serial"])
plt.grid()
plt.savefig("openmpi_gflops_vs_nb_1_core_80_percent_memory.pdf", bbox_inches="tight")
plt.savefig("openmpi_gflops_vs_nb_1_core_80_percent_memory.png", bbox_inches="tight")
plt.show()

# %%
# Hybrid OpenMPI/OpenMP Gflops vs NB for 1 core using 80% memory.

nb = [
    32,
    40,
    48,
    56,
    64,
    72,
    80,
    88,
    96,
    104,
    112,
    120,
    128,
    136,
    144,
    152,
    160,
    168,
    176,
    184,
    192,
    200,
    208,
    216,
    224,
    232,
    240,
    248,
    256
]

openblas_openmp = [
    3.4738e+00,
    3.9920e+00,
    3.8646e+00,
    4.2996e+00,
    4.1936e+00,
    4.4614e+00,
    4.2769e+00,
    4.5300e+00,
    4.4190e+00,
    4.6472e+00,
    4.5432e+00,
    4.7355e+00,
    4.7744e+00,
    4.4922e+00,
    4.4773e+00,
    4.5058e+00,
    4.4988e+00,
    4.5559e+00,
    4.6034e+00,
    4.6161e+00,
    4.6374e+00,
    4.6368e+00,
    4.5972e+00,
    4.6166e+00,
    4.5262e+00,
    4.7554e+00,
    4.7229e+00,
    4.8034e+00,
    4.7744e+00   
]

blis_openmp = [
    2.9813e+00,
    3.2788e+00,
    3.4664e+00,
    3.6604e+00,
    3.7267e+00,
    3.9445e+00,
    4.0123e+00,
    4.1100e+00,
    4.2354e+00,
    4.2921e+00,
    4.3095e+00,
    4.3731e+00,
    4.2167e+00,
    4.5103e+00,
    4.2690e+00,
    4.5673e+00,
    4.6026e+00,
    4.6463e+00,
    4.6668e+00,
    4.6939e+00,
    4.5335e+00,
    4.7521e+00,
    4.8080e+00,
    4.8288e+00,
    4.8622e+00,
    4.8853e+00,
    4.8647e+00,
    4.5139e+00,
    4.3119e+00
]

plt.figure(figsize=(12, 10))
#plt.title("Baseline $R_{max}$ vs NB 1 Core 80% Memory")
plt.plot([32, 256], [R_PEAK_PER_CORE_80, R_PEAK_PER_CORE_80], ":", markersize=6, color="red")
plt.plot(nb, openblas_openmp, "-go", markersize=6)
plt.plot(nb, blis_openmp, "-bo", markersize=6)
plt.xlabel("NB")
plt.ylabel("$R_{max}$ (Gflops)")
plt.legend(["80% $R_{peak}$", "OpenBLAS OpenMP", "BLIS OpenMP"])
plt.grid()
plt.savefig("openmp_gflops_vs_nb_1_core_80_percent_memory.pdf", bbox_inches="tight")
plt.savefig("openmp_gflops_vs_nb_1_core_80_percent_memory.png", bbox_inches="tight")
plt.show()

# %%
# OpenMPI Gflops vs NB for 1 node using 80% memory.

nb = [
    32,
    40,
    48,
    56,
    64,
    72,
    80,
    88,
    96,
    104,
    112,
    120,
    128,
    136,
    144,
    152,
    160,
    168,
    176,
    184,
    192,
    200,
    208,
    216,
    224,
    232,
    240,
    248,
    256
]

openblas_serial = [
    1.0084e+01,
    1.1783e+01,
    1.2137e+01,
    1.3256e+01,
    1.3163e+01,
    1.3915e+01,
    1.3667e+01,
    1.4074e+01,
    1.3942e+01,
    1.4066e+01,
    1.4014e+01,
    1.4108e+01,
    1.3793e+01,
    1.3425e+01,
    1.3617e+01,
    1.3869e+01,
    1.3726e+01,
    1.3795e+01,
    1.3780e+01,
    1.3858e+01,
    1.4104e+01,
    1.3914e+01,
    1.3973e+01,
    1.3934e+01,
    1.3685e+01,
    1.4075e+01,
    1.3827e+01,
    1.3724e+01,
    1.3577e+01   
]

blis_serial = [
    9.2690e+00,
    1.0438e+01,
    1.1300e+01,
    1.2044e+01,
    1.2612e+01,
    1.3392e+01,
    1.3679e+01,
    1.4213e+01,
    1.4428e+01,
    1.4693e+01,
    1.4738e+01,
    1.4931e+01,
    1.5050e+01,
    1.5160e+01,
    1.5174e+01,
    1.5154e+01,
    1.5187e+01,
    1.5168e+01,
    1.5052e+01,
    1.5219e+01,
    1.5006e+01,
    1.4861e+01,
    1.4130e+01,
    1.3755e+01,
    1.3210e+01,
    1.2645e+01,
    1.1920e+01,
    1.1271e+01,
    1.1497e+01
]

plt.figure(figsize=(12, 10))
#plt.title("OpenMPI Baseline $R_{max}$ vs NB 1 Node (4 Cores) 80% Memory")
plt.plot([32, 256], [R_PEAK_80, R_PEAK_80], ":", markersize=6, color="red")
plt.plot(nb, openblas_serial, "-go", markersize=6)
plt.plot(nb, blis_serial, "-bo", markersize=6)
plt.xlabel("NB")
plt.ylabel("$R_{max}$ (Gflops)")
plt.legend(["80% $R_{peak}$", "OpenBLAS Serial", "BLIS Serial"])
plt.grid()
plt.savefig("openmpi_gflops_vs_nb_1_node_80_percent_memory.pdf", bbox_inches="tight")
plt.savefig("openmpi_gflops_vs_nb_1_node_80_percent_memory.png", bbox_inches="tight")
plt.show()

# %%
# Hybrid OpenMPI/OpenMP Gflops vs NB for 1 node using 80% memory.

nb = [
    32,
    40,
    48,
    56,
    64,
    72,
    80,
    88,
    96,
    104,
    112,
    120,
    128,
    136,
    144,
    152,
    160,
    168,
    176,
    184,
    192,
    200,
    208,
    216,
    224,
    232,
    240,
    248,
    256
]

openblas_openmp = [
    9.8562e+00,
    1.1467e+01,
    1.2176e+01,
    1.3329e+01,
    1.3177e+01,
    1.4063e+01,
    1.3692e+01,
    1.4092e+01,
    1.4026e+01,
    1.4335e+01,
    1.3801e+01,
    1.4180e+01,
    1.3612e+01,
    1.3521e+01,
    1.3124e+01,
    1.4062e+01,
    1.3884e+01,
    1.4095e+01,
    1.4164e+01,
    1.4054e+01,
    1.3643e+01,
    1.4200e+01,
    1.4218e+01,
    1.4697e+01,
    1.4254e+01,
    1.4551e+01,
    1.4084e+01,
    1.3974e+01,
    1.2809e+01
]

blis_openmp = [
    9.1541e+00,
    1.0421e+01,
    1.1487e+01,
    1.2067e+01,
    1.2497e+01,
    1.3242e+01,
    1.3362e+01,
    1.3798e+01,
    1.4465e+01,
    1.4589e+01,
    1.4887e+01,
    1.4991e+01,
    1.3214e+01,
    1.5148e+01,
    1.3533e+01,
    1.5560e+01,
    1.5612e+01,
    1.5916e+01,
    1.5895e+01,
    1.5872e+01,
    1.4312e+01,
    1.5954e+01,
    1.6263e+01,
    1.6046e+01,
    1.6012e+01,
    1.6299e+01,
    1.5986e+01,
    1.3791e+01,
    1.2503e+01
]

plt.figure(figsize=(12, 10))
#plt.title("OpenMP Baseline $R_{max}$ vs NB 1 Node (4 Cores) 80% Memory")
plt.plot([32, 256], [R_PEAK_80, R_PEAK_80], ":", markersize=6, color="red")
plt.plot(nb, openblas_openmp, "-go", markersize=6)
plt.plot(nb, blis_openmp, "-bo", markersize=6)
plt.xlabel("NB")
plt.ylabel("$R_{max}$ (Gflops)")
plt.legend(["80% $R_{peak}$", "OpenBLAS OpenMP", "BLIS OpenMP"])
plt.grid()
plt.savefig("openmp_gflops_vs_nb_1_node_80_percent_memory.pdf", bbox_inches="tight")
plt.savefig("openmp_gflops_vs_nb_1_node_80_percent_memory.png", bbox_inches="tight")
plt.savefig("openmp_gflops_vs_nb_1_node_80_percent_memory.pdf", bbox_inches="tight")
plt.savefig("openmp_gflops_vs_nb_1_node_80_percent_memory.png", bbox_inches="tight")
plt.show()

# %%
# Pure OpenMPI Gflops vs NB for 2 nodes using 80% memory.

nb = [
    32,
    40,
    48,
    56,
    64,
    72,
    80,
    88,
    96,
    104,
    112,
    120,
    128,
    136,
    144,
    152,
    160,
    168,
    176,
    184,
    192,
    200,
    208,
    216,
    224,
    232,
    240,
    248,
    256
]

openblas_serial = [
    1.7822e+01,
    2.0908e+01,
    2.2150e+01,
    2.3963e+01,
    2.4105e+01,
    2.5239e+01,
    2.5021e+01,
    2.6050e+01,
    2.5630e+01,
    2.6161e+01,
    2.5813e+01,
    2.6226e+01,
    2.5530e+01,
    2.4364e+01,
    2.4601e+01,
    2.4684e+01,
    2.5075e+01,
    2.5458e+01,
    2.5317e+01,
    2.5951e+01,
    2.5380e+01,
    2.5832e+01,
    2.5538e+01,
    2.5693e+01,
    2.5294e+01,
    2.5979e+01,
    2.5284e+01,
    2.5470e+01,
    2.5187e+01
]

blis_serial = [
    1.6776e+01,
    1.8871e+01,
    2.0267e+01,
    2.1922e+01,
    2.2444e+01,
    2.4171e+01,
    2.5014e+01,
    2.5581e+01,
    2.5658e+01,
    2.6647e+01,
    2.6661e+01,
    2.6922e+01,
    2.6682e+01,
    2.6664e+01,
    2.7284e+01,
    2.7427e+01,
    2.7532e+01,
    2.7814e+01,
    2.7295e+01,
    2.7289e+01,
    2.6772e+01,
    2.7141e+01,
    2.6184e+01,
    2.5754e+01,
    2.4596e+01,
    2.3823e+01,
    2.2350e+01,
    2.1194e+01,
    2.1344e+01
]

plt.figure(figsize=(12, 10))
#plt.title("OpenMPI Baseline $R_{max}$ vs NB 2 Nodes 80% Memory")
plt.plot([32, 256], [R_PEAK_80 * 2, R_PEAK_80 * 2], ":", markersize=6, color="red")
plt.plot(nb, openblas_serial, "-go", markersize=6)
plt.plot(nb, blis_serial, "-bo", markersize=6)
plt.xlabel("NB")
plt.ylabel("$R_{max}$ (Gflops)")
plt.legend(["80% $R_{peak}$", "OpenBLAS Serial", "BLIS Serial"])
plt.grid()
plt.savefig("openmpi_gflops_vs_nb_2_node_80_percent_memory.pdf", bbox_inches="tight")
plt.savefig("openmpi_gflops_vs_nb_2_node_80_percent_memory.png", bbox_inches="tight")
plt.show()

# %%
# Hybrid OpenMPI/OpenMP Gflops vs NB for 2 nodes using 80% memory.

nb = [
    32,
    40,
    48,
    56,
    64,
    72,
    80,
    88,
    96,
    104,
    112,
    120,
    128,
    136,
    144,
    152,
    160,
    168,
    176,
    184,
    192,
    200,
    208,
    216,
    224,
    232,
    240,
    248,
    256
]

openblas_openmp = [
    1.9183e+01,
    2.2089e+01,
    2.3185e+01,
    2.4426e+01,
    2.5094e+01,
    2.5822e+01,
    2.6094e+01,
    2.7303e+01,
    2.6287e+01,
    2.6007e+01,
    2.6402e+01,
    2.6822e+01,
    2.6729e+01,
    2.5811e+01,
    2.5774e+01,
    2.5906e+01,
    2.6189e+01,
    2.6222e+01,
    2.6356e+01,
    2.6819e+01,
    2.6536e+01,
    2.7262e+01,
    2.7262e+01,
    2.6951e+01,
    2.6337e+01,
    2.5963e+01,
    2.6609e+01,
    2.6368e+01,
    2.6296e+01
]

blis_openmp = [
    1.7488e+01,
    1.9945e+01,
    2.1721e+01,
    2.2934e+01,
    2.4608e+01,
    2.4972e+01,
    2.5966e+01,
    2.6843e+01,
    2.7147e+01,
    2.7366e+01,
    2.7937e+01,
    2.8602e+01,
    2.9375e+01,
    2.9461e+01,
    2.9340e+01,
    2.9452e+01,
    2.9748e+01,
    2.9889e+01,
    2.9916e+01,
    3.0251e+01,
    3.0035e+01,
    3.0312e+01,
    2.9205e+01,
    2.8329e+01,
    2.7030e+01,
    2.6309e+01,
    2.4941e+01,
    2.2479e+01,
    2.2185e+01
]

plt.figure(figsize=(12, 10))
#plt.title("OpenMP Baseline $R_{max}$ vs NB 2 Nodes 80% Memory")
plt.plot([32, 256], [R_PEAK_80 * 2, R_PEAK_80 * 2], ":", markersize=6, color="red")
plt.plot(nb, openblas_openmp, "-go", markersize=6)
plt.plot(nb, blis_openmp, "-bo", markersize=6)
plt.xlabel("NB")
plt.ylabel("$R_{max}$ (Gflops)")
plt.legend(["80% $R_{peak}$", "OpenBLAS OpenMP", "BLIS OpenMP"])
plt.grid()
plt.savefig("openmp_gflops_vs_nb_2_node_80_percent_memory.pdf", bbox_inches="tight")
plt.savefig("openmp_gflops_vs_nb_2_node_80_percent_memory.png", bbox_inches="tight")
plt.show()

# %%
# Pure OpenMP Gflops vs Nodes using 80% memory.

nodes = [1, 2, 3, 4, 5, 6, 7, 8]

r_peak_80 = [
    R_PEAK_80 * 1,
    R_PEAK_80 * 2,
    R_PEAK_80 * 3,
    R_PEAK_80 * 4,
    R_PEAK_80 * 5,
    R_PEAK_80 * 6,
    R_PEAK_80 * 7,
    R_PEAK_80 * 8
]

openblas_serial = [
    1.4108e+01,
    2.6226e+01,
    3.3844e+01,
    4.9390e+01,
    5.6513e+01,
    7.3856e+01,
    8.1433e+01,
    9.5525e+01   
]

blis_serial = [
    1.5168e+01,
    2.7814e+01,
    3.9050e+01,
    5.4268e+01,
    6.5226e+01,
    7.9685e+01,
    8.7571e+01,
    1.0341e+02  
]


plt.figure(figsize=(12, 10))
#plt.title("Baseline $R_{max}$ vs Nodes 80% Memory")
plt.plot(nodes, r_peak_80, ":r", markersize=6)
plt.plot(nodes, openblas_serial, "-go", markersize=6)
plt.plot(nodes, blis_serial, "-bo", markersize=6)
plt.xlabel("Nodes")
plt.ylabel("$R_{max}$ (Gflops)")
plt.legend(["80% $R_{peak}$", "OpenBLAS Serial NB=120", "BLIS Serial NB=168"])
plt.grid()
plt.savefig("openmpi_gflops_vs_nodes_80_percent_memory.pdf", bbox_inches="tight")
plt.savefig("openmpi_gflops_vs_nodes_80_percent_memory.png", bbox_inches="tight")
plt.show()

# %%
# Hybrid OpenMPI/OpenMP Gflops vs Nodes using 80% memory.

nodes = [1, 2, 3, 4, 5, 6, 7, 8]

r_peak_80 = [
    R_PEAK_80 * 1,
    R_PEAK_80 * 2,
    R_PEAK_80 * 3,
    R_PEAK_80 * 4,
    R_PEAK_80 * 5,
    R_PEAK_80 * 6,
    R_PEAK_80 * 7,
    R_PEAK_80 * 8
]

openblas_openmp = [
    1.4092e+01,
    2.7303e+01,
    3.7842e+01,
    4.8657e+01,
    6.0428e+01,
    7.3722e+01,
    7.8712e+01,
    9.6630e+01   
]

blis_openmp = [
    1.5954e+01,
    3.0312e+01,
    3.5132e+01,
    4.6953e+01,
    6.2550e+01,
    7.2585e+01,
    8.1255e+01,
    1.0041e+02  
]


plt.figure(figsize=(12, 10))
#plt.title("Baseline $R_{max}$ vs Nodes 80% Memory")
plt.plot(nodes, r_peak_80, ":r", markersize=6)
plt.plot(nodes, openblas_openmp, "-go", markersize=6)
plt.plot(nodes, blis_openmp, "-bo", markersize=6)
plt.xlabel("Nodes")
plt.ylabel("$R_{max}$ (Gflops)")
plt.legend(["80% $R_{peak}$", "OpenBLAS OpenMP NB=88", "BLIS OpenMP NB=200"])
plt.grid()
plt.savefig("openmp_gflops_vs_nodes_80_percent_memory.pdf", bbox_inches="tight")
plt.savefig("openmp_gflops_vs_nodes_80_percent_memory.png", bbox_inches="tight")
plt.show()

# %%
# Network bandwidth vs MTU.

mtu = [
    1000,
    1500,
    2000,
    3000,
    4000,
    5000,
    6000,
    7000,
    8000,
    9000
]

bandwidth = [
    809,
    922,
    958,
    968,
    977,
    983,
    986,
    988,
    990,
    991
]


plt.figure(figsize=(12, 10))
#plt.title("Network Node to Node Bandwidth vs MTU")
plt.plot([1000, 9000], [1000, 1000], "--r", markersize=5)
plt.plot(mtu, bandwidth, "-bo", markersize=6)
plt.plot([1500], [922], "go", markersize=8)
plt.xlabel("MTU")
plt.ylabel("Bandwidth (Mbit/s)")
plt.legend(["1Gbit/s", "node1 $\longleftrightarrow$ node2", "Default MTU = 1500"])
plt.grid()
plt.savefig("bandwidth_vs_mtu.pdf", bbox_inches="tight")
plt.savefig("bandwidth_vs_mtu.png", bbox_inches="tight")
plt.show()

# %%
# MTU 9000 Gflops vs Nodes using 80% memory.

nodes = [1, 2, 3, 4, 5, 6, 7, 8]

r_peak_80 = [
    R_PEAK_80 * 1,
    R_PEAK_80 * 2,
    R_PEAK_80 * 3,
    R_PEAK_80 * 4,
    R_PEAK_80 * 5,
    R_PEAK_80 * 6,
    R_PEAK_80 * 7,
    R_PEAK_80 * 8
]

blis_p1_1500 = [
    1.5045e+01,
    2.7240e+01,
    4.0522e+01,
    5.1390e+01,
    6.2685e+01,
    7.3622e+01,
    8.2960e+01,
    9.1411e+01  
]

blis_p2_1500 = [
    1.5045e+01,
    2.7742e+01,
    3.9531e+01,
    5.3333e+01,
    6.5231e+01,
    8.0164e+01,
    8.9984e+01,
    1.0315e+02  
]

blis_p1_9000 = [
    1.5208e+01,
    2.7767e+01,
    4.1503e+01,
    5.3604e+01,
    6.5496e+01,
    7.6772e+01,
    8.8257e+01,
    9.7589e+01  
]

blis_p2_9000 = [
    blis_p2_1500[0] * blis_p1_9000[0] / blis_p1_1500[0],
    blis_p2_1500[1] * blis_p1_9000[1] / blis_p1_1500[1],
    blis_p2_1500[2] * blis_p1_9000[2] / blis_p1_1500[2],
    blis_p2_1500[3] * blis_p1_9000[3] / blis_p1_1500[3],
    blis_p2_1500[4] * blis_p1_9000[4] / blis_p1_1500[4],
    blis_p2_1500[5] * blis_p1_9000[5] / blis_p1_1500[5],
    blis_p2_1500[6] * blis_p1_9000[6] / blis_p1_1500[6],
    blis_p2_1500[7] * blis_p1_9000[7] / blis_p1_1500[7]  
]

plt.figure(figsize=(12, 10))
#plt.title("MTU 9000 $R_{max}$ vs Nodes 80% Memory")
plt.plot(nodes, r_peak_80, ":r", markersize=6)
plt.plot(nodes, blis_p1_1500, ":", markersize=6, color="steelblue")
plt.plot(nodes, blis_p1_9000, "-o", markersize=6, color="steelblue")
plt.plot(nodes, blis_p2_1500, ":b", markersize=6)
plt.plot(nodes, blis_p2_9000, "-bo", markersize=6)
plt.xlabel("Nodes")
plt.ylabel("$R_{max}$ (Gflops)")
plt.legend(["80% $R_{peak}$",
            "BLIS P=1 MTU=1500",
            "BLIS P=1 MTU=9000",
            "BLIS P=2 MTU=1500",
            "BLIS P=2 MTU=9000 (Anticipated)"])
plt.grid()
plt.savefig("gflops_vs_nodes_80_percent_memory_mtu_9000.pdf", bbox_inches="tight")
plt.savefig("gflops_vs_nodes_80_percent_memory_mtu_9000.png", bbox_inches="tight")
plt.show()

# %%
# Profile No-Preemption.

nb = [
    32,
    40,
    48,
    56,
    64,
    72,
    80,
    88,
    96,
    104,
    112,
    120,
    128,
    136,
    144,
    152,
    160,
    168,
    176,
    184,
    192,
    200,
    208,
    216,
    224,
    232,
    240,
    248,
    256
]

openblas_serial = [
    4.4798e+01,
    4.9108e+01,
    5.1916e+01,
    5.3983e+01,
    5.5073e+01,
    5.5830e+01,
    5.5865e+01,
    5.6509e+01,
    5.6328e+01,
    5.6728e+01,
    5.6772e+01,
    5.6183e+01,
    5.5742e+01,
    5.5154e+01,
    5.4458e+01,
    5.5080e+01,
    5.3606e+01,
    5.4744e+01,
    5.4921e+01,
    5.3758e+01,
    5.4802e+01,
    5.3967e+01,
    5.4310e+01,
    5.3641e+01,
    5.3353e+01,
    5.3029e+01,
    5.3431e+01,
    5.3555e+01,
    5.3359e+01
]

openblas_openmp = [
    4.7513e+01,
    5.1224e+01,
    5.3885e+01,
    5.6555e+01,
    5.8729e+01,
    5.9543e+01,
    5.7510e+01,
    5.7970e+01,
    5.7670e+01,
    5.8127e+01,
    5.6534e+01,
    5.6417e+01,
    5.7026e+01,
    5.7562e+01,
    5.6849e+01,
    5.6090e+01,
    5.7672e+01,
    5.6918e+01,
    5.6828e+01,
    5.6280e+01,
    5.7208e+01,
    5.7684e+01,
    5.7208e+01,
    5.5505e+01,
    5.6530e+01,
    5.4688e+01,
    5.4656e+01,
    5.4629e+01,
    5.4347e+01
]

blis_serial = [
    4.2145e+01,
    4.6786e+01,
    4.9423e+01,
    5.0965e+01,
    5.2102e+01,
    5.4340e+01,
    5.5373e+01,
    5.6268e+01,
    5.5691e+01,
    5.5986e+01,
    5.6550e+01,
    5.7238e+01,
    5.5206e+01,
    5.7152e+01,
    5.7208e+01,
    5.6735e+01,
    5.5166e+01,
    5.5882e+01,
    5.4975e+01,
    5.5330e+01,
    5.4564e+01,
    5.4360e+01,
    5.3998e+01,
    5.2345e+01,
    5.0687e+01,
    5.0299e+01,
    4.9333e+01,
    4.7440e+01,
    4.7428e+01
]

blis_openmp = [
    4.6267e+01,
    5.0272e+01,
    5.2327e+01,
    5.5051e+01,
    5.6932e+01,
    5.8497e+01,
    5.9106e+01,
    5.9774e+01,
    6.0430e+01,
    6.0202e+01,
    6.0482e+01,
    6.0753e+01,
    6.0666e+01,
    6.2253e+01,
    6.1768e+01,
    6.1955e+01,
    6.3326e+01,
    6.2892e+01,
    6.2247e+01,
    6.1225e+01,
    6.2034e+01,
    5.9953e+01,
    6.0651e+01,
    5.7819e+01,
    5.3805e+01,
    5.8601e+01,
    5.5472e+01,
    5.2420e+01,
    5.3883e+01
]

plt.figure(figsize=(12, 10))
plt.plot(nb, openblas_serial, "-go", markersize=6)
plt.plot(nb, openblas_openmp, "-mo", markersize=6)
plt.plot(nb, blis_serial, "-bo", markersize=6)
plt.plot(nb, blis_openmp, "-co", markersize=6)
plt.xlabel("NB")
plt.ylabel("$R_{max}$ (Gflops)")
plt.legend(["OpenBLAS Serial", "OpenBLAS OpenMP", "BLIS Serial", "BLIS OpenMP"])
plt.grid()
plt.savefig("profile_nopreempt.pdf", bbox_inches="tight")
plt.savefig("profile_nopreempt.png", bbox_inches="tight")
plt.show()

# %%
# Profile Baseline.

nb = [
    32,
    40,
    48,
    56,
    64,
    72,
    80,
    88,
    96,
    104,
    112,
    120,
    128,
    136,
    144,
    152,
    160,
    168,
    176,
    184,
    192,
    200,
    208,
    216,
    224,
    232,
    240,
    248,
    256
]

openblas_serial = [
42.499000,
47.184000,
50.119000,
52.818000,
53.510000,
53.937000,
54.121000,
54.942000,
54.274000,
54.545000,
54.600000,
54.889000,
54.234000,
52.403000,
53.136000,
53.245000,
51.728000,
52.862000,
52.414000,
52.707000,
52.406000,
52.695000,
51.966000,
51.412000,
51.472000,
51.555000,
51.856000,
50.662000,
52.074000,
]

openblas_openmp = [
44.118000,
48.819000,
52.371000,
53.874000,
56.693000,
56.992000,
56.204000,
55.966000,
57.815000,
56.408000,
55.799000,
55.332000,
54.974000,
55.242000,
55.567000,
55.470000,
55.375000,
56.331000,
54.765000,
54.895000,
56.064000,
56.326000,
55.198000,
54.874000,
54.284000,
54.412000,
52.362000,
53.203000,
54.770000,
]

blis_serial = [
40.774000,
44.512000,
47.008000,
49.627000,
50.347000,
51.889000,
53.055000,
54.751000,
53.347000,
54.240000,
54.277000,
54.032000,
53.633000,
54.683000,
54.623000,
54.034000,
53.334000,
54.212000,
53.451000,
53.249000,
53.394000,
52.344000,
51.653000,
50.364000,
49.245000,
48.066000,
47.528000,
44.584000,
45.362000,
]

blis_openmp = [
44.639000,
47.503000,
51.639000,
52.229000,
54.633000,
56.136000,
56.490000,
57.044000,
58.979000,
58.846000,
59.608000,
59.662000,
59.076000,
60.021000,
60.232000,
59.908000,
60.069000,
60.167000,
59.633000,
59.853000,
60.015000,
59.244000,
57.855000,
58.106000,
57.761000,
56.602000,
54.488000,
51.039000,
49.784000,
]

plt.figure(figsize=(12, 10))
plt.plot(nb, openblas_serial, "-go", markersize=6)
plt.plot(nb, openblas_openmp, "-mo", markersize=6)
plt.plot(nb, blis_serial, "-bo", markersize=6)
plt.plot(nb, blis_openmp, "-co", markersize=6)
plt.xlabel("NB")
plt.ylabel("$R_{max}$ (Gflops)")
plt.legend(["OpenBLAS Serial", "OpenBLAS OpenMP", "BLIS Serial", "BLIS OpenMP"])
plt.grid()
plt.savefig("profile_baseline.pdf", bbox_inches="tight")
plt.savefig("profile_baseline.png", bbox_inches="tight")
plt.show()

# %%
# Profile Interrupt Coalescing.

nb = [
    32,
    40,
    48,
    56,
    64,
    72,
    80,
    88,
    96,
    104,
    112,
    120,
    128,
    136,
    144,
    152,
    160,
    168,
    176,
    184,
    192,
    200,
    208,
    216,
    224,
    232,
    240,
    248,
    256
]

openblas_serial = [
42.208000,
46.997000,
49.197000,
52.817000,
53.757000,
54.104000,
53.807000,
54.135000,
54.948000,
55.614000,
54.355000,
54.530000,
54.563000,
52.317000,
53.187000,
53.235000,
52.328000,
52.991000,
52.442000,
52.763000,
52.310000,
52.873000,
52.655000,
51.429000,
51.846000,
51.073000,
51.914000,
51.049000,
51.787000,
]

openblas_openmp = [
44.459000,
49.766000,
51.769000,
54.203000,
55.311000,
57.189000,
55.718000,
55.784000,
57.054000,
56.206000,
56.309000,
54.856000,
55.404000,
54.935000,
54.628000,
55.421000,
55.793000,
56.118000,
55.681000,
54.920000,
55.607000,
55.747000,
56.169000,
52.502000,
55.159000,
53.580000,
53.327000,
53.098000,
54.634000,
]

blis_serial = [
40.806000,
44.841000,
46.979000,
49.853000,
50.458000,
52.102000,
53.848000,
54.150000,
53.558000,
53.832000,
54.063000,
53.919000,
54.300000,
53.864000,
54.486000,
54.253000,
53.807000,
54.564000,
52.257000,
52.825000,
52.008000,
52.169000,
51.926000,
50.070000,
49.168000,
47.588000,
46.972000,
44.595000,
45.865000,
]

blis_openmp = [
44.197000,
47.817000,
51.358000,
53.161000,
55.164000,
55.507000,
56.980000,
57.646000,
58.478000,
58.723000,
59.413000,
59.404000,
59.102000,
59.379000,
60.398000,
59.441000,
59.958000,
60.091000,
59.960000,
59.608000,
60.078000,
59.325000,
58.982000,
58.837000,
57.934000,
51.360000,
47.572000,
49.576000,
50.976000,
]

plt.figure(figsize=(12, 10))
plt.plot(nb, openblas_serial, "-go", markersize=6)
plt.plot(nb, openblas_openmp, "-mo", markersize=6)
plt.plot(nb, blis_serial, "-bo", markersize=6)
plt.plot(nb, blis_openmp, "-co", markersize=6)
plt.xlabel("NB")
plt.ylabel("$R_{max}$ (Gflops)")
plt.legend(["OpenBLAS Serial", "OpenBLAS OpenMP", "BLIS Serial", "BLIS OpenMP"])
plt.grid()
plt.savefig("profile_interrupt_coalescing.pdf", bbox_inches="tight")
plt.savefig("profile_interrupt_coalescing.png", bbox_inches="tight")
plt.show()

# %%
# Profile RPS RFS.

nb = [
    32,
    40,
    48,
    56,
    64,
    72,
    80,
    88,
    96,
    104,
    112,
    120,
    128,
    136,
    144,
    152,
    160,
    168,
    176,
    184,
    192,
    200,
    208,
    216,
    224,
    232,
    240,
    248,
    256
]

openblas_serial = [
42.787000,
47.798000,
50.363000,
53.092000,
54.223000,
54.339000,
54.485000,
55.480000,
54.926000,
54.782000,
54.745000,
55.156000,
54.390000,
52.729000,
53.201000,
53.326000,
52.688000,
52.708000,
53.312000,
53.299000,
53.335000,
52.483000,
53.020000,
50.936000,
52.175000,
51.712000,
51.965000,
51.542000,
51.636000,
]

openblas_openmp = [
44.302000,
48.172000,
51.754000,
54.203000,
55.702000,
56.928000,
56.703000,
55.498000,
54.649000,
56.605000,
56.080000,
48.536000,
54.042000,
54.823000,
55.860000,
55.199000,
55.986000,
55.668000,
55.881000,
55.140000,
55.806000,
56.114000,
55.886000,
54.048000,
52.621000,
54.235000,
52.209000,
51.368000,
53.373000,
]

blis_serial = [
41.106000,
45.074000,
47.541000,
49.993000,
50.526000,
52.435000,
54.191000,
54.455000,
54.276000,
53.956000,
55.134000,
55.014000,
54.382000,
53.688000,
55.265000,
54.422000,
53.225000,
53.870000,
53.606000,
53.966000,
52.888000,
51.595000,
51.773000,
50.476000,
49.273000,
48.282000,
47.309000,
44.259000,
45.760000,
]

blis_openmp = [
44.313000,
48.105000,
51.144000,
52.723000,
55.290000,
55.638000,
57.072000,
57.978000,
58.862000,
59.427000,
59.170000,
59.587000,
59.052000,
59.324000,
60.344000,
60.056000,
59.862000,
60.037000,
59.346000,
58.029000,
59.029000,
58.597000,
53.726000,
54.523000,
55.517000,
53.730000,
50.509000,
47.319000,
47.928000,
]

plt.figure(figsize=(12, 10))
plt.plot(nb, openblas_serial, "-go", markersize=6)
plt.plot(nb, openblas_openmp, "-mo", markersize=6)
plt.plot(nb, blis_serial, "-bo", markersize=6)
plt.plot(nb, blis_openmp, "-co", markersize=6)
plt.xlabel("NB")
plt.ylabel("$R_{max}$ (Gflops)")
plt.legend(["OpenBLAS Serial", "OpenBLAS OpenMP", "BLIS Serial", "BLIS OpenMP"])
plt.grid()
plt.savefig("profile_rps_rfs.pdf", bbox_inches="tight")
plt.savefig("profile_rps_rfs.png", bbox_inches="tight")
plt.show()

# %%
# Profile Aggregate.

nb = [
    32,
    40,
    48,
    56,
    64,
    72,
    80,
    88,
    96,
    104,
    112,
    120,
    128,
    136,
    144,
    152,
    160,
    168,
    176,
    184,
    192,
    200,
    208,
    216,
    224,
    232,
    240,
    248,
    256
]

openblas_serial = [
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40

]

openblas_openmp = [
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40

]

blis_serial = [
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40
]

blis_openmp = [
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40
]

plt.figure(figsize=(12, 10))
plt.plot(nb, openblas_serial, "-go", markersize=6)
plt.plot(nb, openblas_openmp, "-mo", markersize=6)
plt.plot(nb, blis_serial, "-bo", markersize=6)
plt.plot(nb, blis_openmp, "-co", markersize=6)
plt.xlabel("NB")
plt.ylabel("$R_{max}$ (Gflops)")
plt.legend(["OpenBLAS Serial", "OpenBLAS OpenMP", "BLIS Serial", "BLIS OpenMP"])
plt.grid()
plt.savefig("profile_aggregate.pdf", bbox_inches="tight")
plt.savefig("profile_aggregate.png", bbox_inches="tight")
plt.show()

# %%
# Profile BLIS Serial.

nb = [
    32,
    40,
    48,
    56,
    64,
    72,
    80,
    88,
    96,
    104,
    112,
    120,
    128,
    136,
    144,
    152,
    160,
    168,
    176,
    184,
    192,
    200,
    208,
    216,
    224,
    232,
    240,
    248,
    256
]

baseline = [
40.774000,
44.512000,
47.008000,
49.627000,
50.347000,
51.889000,
53.055000,
54.751000,
53.347000,
54.240000,
54.277000,
54.032000,
53.633000,
54.683000,
54.623000,
54.034000,
53.334000,
54.212000,
53.451000,
53.249000,
53.394000,
52.344000,
51.653000,
50.364000,
49.245000,
48.066000,
47.528000,
44.584000,
45.362000,
]


interrupt_coalescing = [
40.806000,
44.841000,
46.979000,
49.853000,
50.458000,
52.102000,
53.848000,
54.150000,
53.558000,
53.832000,
54.063000,
53.919000,
54.300000,
53.864000,
54.486000,
54.253000,
53.807000,
54.564000,
52.257000,
52.825000,
52.008000,
52.169000,
51.926000,
50.070000,
49.168000,
47.588000,
46.972000,
44.595000,
45.865000,
]

rps_rfs = [
41.106000,
45.074000,
47.541000,
49.993000,
50.526000,
52.435000,
54.191000,
54.455000,
54.276000,
53.956000,
55.134000,
55.014000,
54.382000,
53.688000,
55.265000,
54.422000,
53.225000,
53.870000,
53.606000,
53.966000,
52.888000,
51.595000,
51.773000,
50.476000,
49.273000,
48.282000,
47.309000,
44.259000,
45.760000,
]

no_preemption = [
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40
]

aggregate = [
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40
]

plt.figure(figsize=(12, 10))
plt.plot(nb, baseline, "-go", markersize=6)
plt.plot(nb, interrupt_coalescing, "-co", markersize=6)
plt.plot(nb, rps_rfs, "-bo", markersize=6)
plt.plot(nb, no_preemption, "-mo", markersize=6)
plt.plot(nb, aggregate, "-ro", markersize=6)
plt.xlabel("NB")
plt.xlabel("NB")
plt.ylabel("$R_{max}$ (Gflops)")
plt.legend(["Baseline", "Interrupt Coalescing", "RPS RFS", "No Preemption", "Aggregate"])
plt.grid()
plt.savefig("profile_blis_serial.pdf", bbox_inches="tight")
plt.savefig("profile_blis_serial.png", bbox_inches="tight")
plt.show()

# %%
# Profile BLIS OpenMP.

nb = [
    32,
    40,
    48,
    56,
    64,
    72,
    80,
    88,
    96,
    104,
    112,
    120,
    128,
    136,
    144,
    152,
    160,
    168,
    176,
    184,
    192,
    200,
    208,
    216,
    224,
    232,
    240,
    248,
    256
]

baseline = [
44.639000,
47.503000,
51.639000,
52.229000,
54.633000,
56.136000,
56.490000,
57.044000,
58.979000,
58.846000,
59.608000,
59.662000,
59.076000,
60.021000,
60.232000,
59.908000,
60.069000,
60.167000,
59.633000,
59.853000,
60.015000,
59.244000,
57.855000,
58.106000,
57.761000,
56.602000,
54.488000,
51.039000,
49.784000,
]

interrupt_coalescing = [
44.197000,
47.817000,
51.358000,
53.161000,
55.164000,
55.507000,
56.980000,
57.646000,
58.478000,
58.723000,
59.413000,
59.404000,
59.102000,
59.379000,
60.398000,
59.441000,
59.958000,
60.091000,
59.960000,
59.608000,
60.078000,
59.325000,
58.982000,
58.837000,
57.934000,
51.360000,
47.572000,
49.576000,
50.976000,
]

rps_rfs = [
44.313000,
48.105000,
51.144000,
52.723000,
55.290000,
55.638000,
57.072000,
57.978000,
58.862000,
59.427000,
59.170000,
59.587000,
59.052000,
59.324000,
60.344000,
60.056000,
59.862000,
60.037000,
59.346000,
58.029000,
59.029000,
58.597000,
53.726000,
54.523000,
55.517000,
53.730000,
50.509000,
47.319000,
47.928000,
]

no_preemption = [
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40
]

aggregate = [
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40,
    40
]

plt.figure(figsize=(12, 10))
plt.plot(nb, baseline, "-go", markersize=6)
plt.plot(nb, interrupt_coalescing, "-co", markersize=6)
plt.plot(nb, rps_rfs, "-bo", markersize=6)
plt.plot(nb, no_preemption, "-mo", markersize=6)
plt.plot(nb, aggregate, "-ro", markersize=6)
plt.xlabel("NB")
plt.xlabel("NB")
plt.ylabel("$R_{max}$ (Gflops)")
plt.legend(["Baseline", "Interrupt Coalescing", "RPS RFS", "No Preemption", "Aggregate"])
plt.grid()
plt.savefig("profile_blis_serial.pdf", bbox_inches="tight")
plt.savefig("profile_blis_serial.png", bbox_inches="tight")
plt.show()

# %%
# Profile ARMPL.

nb = [
    32,
    40,
    48,
    56,
    64,
    72,
    80,
    88,
    96,
    104,
    112,
    120,
    128,
    136,
    144,
    152,
    160,
    168,
    176,
    184,
    192,
    200,
    208,
    216,
    224,
    232,
    240,
    248,
    256
]

serial = [
43.055000,
48.916000,
51.166000,
51.996000,
52.400000,
52.608000,
51.624000,
52.153000,
52.329000,
51.647000,
52.192000,
52.060000,
50.722000,
22.087000,
21.455000,
21.380000,
21.935000,
20.673000,
20.539000,
20.760000,
21.440000,
20.579000,
19.865000,
20.149000,
20.373000,
18.831000,
19.104000,
19.688000,
19.988000,
]

openmp = [
45.674000,
49.865000,
53.005000,
54.352000,
52.911000,
54.700000,
52.584000,
52.874000,
53.110000,
53.537000,
52.055000,
52.452000,
48.357000,
49.806000,
45.992000,
41.981000,
41.013000,
37.998000,
33.731000,
32.513000,
31.495000,
30.695000,
29.630000,
29.042000,
28.146000,
27.818000,
27.576000,
27.821000,
27.879000,
]

plt.figure(figsize=(12, 10))
plt.plot(nb, serial, "-go", markersize=6)
plt.plot(nb, openmp, "-co", markersize=6)
plt.xlabel("NB")
plt.ylabel("$R_{max}$ (Gflops)")
plt.legend(["Serial", "OpenMP"])
plt.grid()
plt.savefig("profile_armpl_serial.pdf", bbox_inches="tight")
plt.savefig("profile_armpl_openmp.png", bbox_inches="tight")
plt.show()
